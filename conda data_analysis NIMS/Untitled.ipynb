# %%
#ルーレット選択法
import random

individuals=[-1,1,5]
def selectRoulette(individuals):
    class MyClass:
        def __init__(self, value):
            self.value = value

        def getScore(self):
            return self.value

    # 整数のリストをカスタムクラスのインスタンスに変換
    individuals=[-1,1,5]
    instances = [MyClass(x) for x in individuals]

    # 各インスタンスの getScore() メソッドを呼び出してスコアを取得
    weights = [instance.getScore() for instance in instances]

    print(weights)

    w_min = min(weights)
    if w_min < 0:
        # 最小が負の場合は基準を0→w_min→に変更
        weights = [w + (-w_min * 2) for w in weights]

    # 重さの合計で乱数を出す
    r = random.random() * sum(weights)

    # 重さを順番に見ていき、乱数以下ならそのindexが該当
    num = 0
    for i, weight in enumerate(weights):
        num += weight
        if r <= num:
            return individuals[i]

    assert False, "ここには来ないはず"

# %%
#ルーレット選択法
import random

individuals=[-1,1,5]
def selectRoulette(individuals):
    class MyClass:
        def __init__(self, value):
            self.value = value

        def getScore(self):
            return self.value

    # 整数のリストをカスタムクラスのインスタンスに変換
    individuals=[-1,1,5]
    instances = [MyClass(x) for x in individuals]

    # 各インスタンスの getScore() メソッドを呼び出してスコアを取得
    weights = [instance.getScore() for instance in instances]

    print(weights)

    w_min = min(weights)
    if w_min < 0:
        # 最小が負の場合は基準を0→w_min→に変更
        weights = [w + (-w_min * 2) for w in weights]

    # 重さの合計で乱数を出す
    r = random.random() * sum(weights)

    # 重さを順番に見ていき、乱数以下ならそのindexが該当
    num = 0
    for i, weight in enumerate(weights):
        num += weight
        if r <= num:
            return individuals[i]

    assert False, "ここには来ないはず"
